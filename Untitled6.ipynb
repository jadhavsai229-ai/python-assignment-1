# %% [markdown]
# <a href="https://colab.research.google.com/github/jadhavsai229-ai/python-assignment-1/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Demonstration of Python Data Types

# Integer
a = 10
print("Integer value:", a)

# Float
b = 5.75
print("Float value:", b)

# String
c = "Hello Python"
print("String value:", c)

# Boolean
d = True
print("Boolean value:", d)

# List
e = [1, 2, 3, 4]
print("List value:", e)

# Tuple
f = (10, 20, 30)
print("Tuple value:", f)

# Dictionary
g = {"Name": "Sai", "Age": 19}
print("Dictionary value:", g)

# Set
h = {1, 2, 3, 4}
print("Set value:", h)
# Out:
# Integer value: 10
# Float value: 5.75
# String value: Hello Python
# Boolean value: True
# List value: [1, 2, 3, 4]
# Tuple value: (10, 20, 30)
# Dictionary value: {'Name': 'Sai', 'Age': 19}
# Set value: {1, 2, 3, 4}
